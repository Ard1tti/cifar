# %%
import os
os.chdir('/home/blueconet/Downloads/Image Classification')

# %%
from cifar_input import cifar10_input
import ResNet_cifar10_ed as model
import tensorflow as tf

BATCH_SIZE=16
EVAL_SIZE=1000
NUM_GPUS=8

def tower_loss(batch, scope):
    images, labels = batch
    
    logits = model.inference(images, keep_prob)
    _ = model.loss(logits, labels)
    
    losses = tf.get_collection('losses', scope)
    
    total_loss = tf.add_n(losses, name='total_loss')
    return total_loss

def average_grads(list_grads):
    grads = [(tf.reduce_mean([list_grads[j][i][0] for j in range(len(list_grads))],
                             0),
             list_grads[0][i][1]) for i in range(len(list_grads[0]))]
    return grads

# %%
with tf.Graph().as_default(), tf.device("/cpu:0"):
    train_data, test_data = cifar10_input()
    
    train_batch = train_data.dist_batch(BATCH_SIZE,20000)
    test_batch = test_data.batch(200)

    x = tf.placeholder(tf.float32, [None, 32, 32, 3])
    y_ = tf.placeholder(tf.int32, [x.get_shape()[0]])
    keep_prob = tf.placeholder(tf.float32)
    lr = tf.placeholder(tf.float32)
    opt = tf.train.GradientDescentOptimizer(lr)

    with tf.device('/gpu:0'):
        logit = model.inference(x, keep_prob)
        loss = model.loss(logit, y_)
        grads = opt.compute_gradients(loss)    
    
    train_op = opt.apply_gradients(grads)
    sess = tf.Session()
    
    rate = 0.1
    
    sess.run(tf.initialize_all_variables())
    tf.train.start_queue_runners(sess=sess)
    for i in range(20):
        image_batch, label_batch = sess.run(train_batch)
        _, cross_entropy = sess.run([train_op, loss], feed_dict = {x: image_batch, y_: label_batch, keep_prob: 0.5, lr:rate})
        print("step %d, cross_entropy %g"%(i, cross_entropy))
# Out:
# step 0, cross_entropy 5.09146
# step 1, cross_entropy 5.57883
# step 2, cross_entropy 5.12233
# step 3, cross_entropy 5.08339
# step 4, cross_entropy 4.92274
# step 5, cross_entropy 4.92234
# step 6, cross_entropy 4.81229
# step 7, cross_entropy 4.84537
# step 8, cross_entropy 4.89351
# step 9, cross_entropy 4.77091
# step 10, cross_entropy 4.75525
# step 11, cross_entropy 4.63286
# step 12, cross_entropy 4.82945
# step 13, cross_entropy 4.63553
# step 14, cross_entropy 4.80319
# step 15, cross_entropy 4.54083
# step 16, cross_entropy 4.49254
# step 17, cross_entropy 4.55385
# step 18, cross_entropy 4.60916
# step 19, cross_entropy 4.56456

# %%
with tf.Graph().as_default(), tf.device("/cpu:0"):
        train_data, test_data = cifar10_input()
        
        train_batch = train_data.dist_batch(BATCH_SIZE, 20000)
        images, labels = test_data.dist_batch(EVAL_SIZE, 4000)

        keep_prob = tf.placeholder(tf.float32)
        lr = tf.placeholder(tf.float32)

        logit = model.inference(images, keep_prob)
        accuracy = tf.reduce_mean(tf.cast(tf.nn.in_top_k(logit, labels, 1),tf.float32))
        tf.get_variable_scope().reuse_variables()
        
        opt = tf.train.GradientDescentOptimizer(lr)

        with tf.device('/gpu:0'):
            with tf.name_scope('%s_%d' % ('tower', 0)) as scope:
                loss = tower_loss(train_batch, scope)
                grads = opt.compute_gradients(loss)    
    
        train_op = opt.apply_gradients(grads)
        sess = tf.Session()
        
        rate = 0.1
        mean_loss = 0.
        least = 10.
        count = 0.
    
        sess.run(tf.initialize_all_variables())
        tf.train.start_queue_runners(sess=sess)
        for i in range(20000):
            _, cross_entropy = sess.run([train_op, loss], feed_dict = {keep_prob: 0.5,
                                                                       lr:rate})
            mean_loss = mean_loss + cross_entropy/50
    
            if i%50 == 0 and i>0:
                print("step %d, cross_entropy %g"%(i, mean_loss))
      
                if mean_loss > least:
                    count = count+1
                    if count > 4:
                        rate = rate/2.0
                        count = 0
                    else:
                        count = 0
                        least = mean_loss
                mean_loss=0
        
            if i%250 == 0 and i>0:
                eval_accuracy = sess.run(accuracy)
                print("test accuracy %g"%(eval_accuracy))
# Out:
# step 50, cross_entropy 2.34179
# step 100, cross_entropy 2.20467
# step 150, cross_entropy 2.11237
# step 200, cross_entropy 2.05938
# step 250, cross_entropy 2.01351
# test accuracy 0.236
# step 300, cross_entropy 2.01619
# step 350, cross_entropy 1.96637
# step 400, cross_entropy 1.9585
# step 450, cross_entropy 1.9671
# step 500, cross_entropy 1.93296
# test accuracy 0.236
# step 550, cross_entropy 1.94518
# step 600, cross_entropy 1.89222
# step 650, cross_entropy 1.88125
# step 700, cross_entropy 1.83801
# step 750, cross_entropy 1.85326
# test accuracy 0.317
# step 800, cross_entropy 1.86021
# step 850, cross_entropy 1.83193
# step 900, cross_entropy 1.80373
# step 950, cross_entropy 1.77622
# step 1000, cross_entropy 1.78349
# test accuracy 0.332
# step 1050, cross_entropy 1.80523
# step 1100, cross_entropy 1.79015
# step 1150, cross_entropy 1.73958
# step 1200, cross_entropy 1.72495
# step 1250, cross_entropy 1.76043
# test accuracy 0.333
# step 1300, cross_entropy 1.75862
# step 1350, cross_entropy 1.7238
# step 1400, cross_entropy 1.73104
# step 1450, cross_entropy 1.72285
# step 1500, cross_entropy 1.73541
# test accuracy 0.286
# step 1550, cross_entropy 1.69347
# step 1600, cross_entropy 1.71747
# step 1650, cross_entropy 1.69615
# step 1700, cross_entropy 1.69151
# step 1750, cross_entropy 1.64308
# test accuracy 0.428
# step 1800, cross_entropy 1.6617
# step 1850, cross_entropy 1.67732
# step 1900, cross_entropy 1.64392
# step 1950, cross_entropy 1.67179
# step 2000, cross_entropy 1.66823
# test accuracy 0.374
# step 2050, cross_entropy 1.60087
# step 2100, cross_entropy 1.62467
# step 2150, cross_entropy 1.60061
# step 2200, cross_entropy 1.60436
# step 2250, cross_entropy 1.59094
# test accuracy 0.358
# step 2300, cross_entropy 1.61948
# step 2350, cross_entropy 1.53394
# step 2400, cross_entropy 1.57372
# step 2450, cross_entropy 1.54793
# step 2500, cross_entropy 1.5563
# test accuracy 0.463
# step 2550, cross_entropy 1.53577
# step 2600, cross_entropy 1.5341
# step 2650, cross_entropy 1.55005
# step 2700, cross_entropy 1.54322
# step 2750, cross_entropy 1.53584
# test accuracy 0.397
# step 2800, cross_entropy 1.48748
# step 2850, cross_entropy 1.46871
# step 2900, cross_entropy 1.49357
# step 2950, cross_entropy 1.41543
# step 3000, cross_entropy 1.46244
# test accuracy 0.449
# step 3050, cross_entropy 1.47004
# step 3100, cross_entropy 1.45178
# step 3150, cross_entropy 1.38085
# step 3200, cross_entropy 1.44198
# step 3250, cross_entropy 1.38487
# test accuracy 0.514
# step 3300, cross_entropy 1.40711
# step 3350, cross_entropy 1.38131
# step 3400, cross_entropy 1.41269
# step 3450, cross_entropy 1.40075
# step 3500, cross_entropy 1.37188
# test accuracy 0.503
# step 3550, cross_entropy 1.37776
# step 3600, cross_entropy 1.35684
# step 3650, cross_entropy 1.39134
# step 3700, cross_entropy 1.329
# step 3750, cross_entropy 1.34636
# test accuracy 0.497
# step 3800, cross_entropy 1.33249
# step 3850, cross_entropy 1.31793
# step 3900, cross_entropy 1.33607
# step 3950, cross_entropy 1.33217
# step 4000, cross_entropy 1.31007
# test accuracy 0.564
# step 4050, cross_entropy 1.25707
# step 4100, cross_entropy 1.25842
# step 4150, cross_entropy 1.27156
# step 4200, cross_entropy 1.24808
# step 4250, cross_entropy 1.27132
# test accuracy 0.471
# step 4300, cross_entropy 1.23014
# step 4350, cross_entropy 1.26902
# step 4400, cross_entropy 1.26203
# step 4450, cross_entropy 1.24924
# step 4500, cross_entropy 1.22493
# test accuracy 0.56
# step 4550, cross_entropy 1.24047
# step 4600, cross_entropy 1.22827
# step 4650, cross_entropy 1.25829
# step 4700, cross_entropy 1.19746
# step 4750, cross_entropy 1.19545
# test accuracy 0.601
# step 4800, cross_entropy 1.18176
# step 4850, cross_entropy 1.16691
# step 4900, cross_entropy 1.16892
# step 4950, cross_entropy 1.17225
# step 5000, cross_entropy 1.17067
# test accuracy 0.531
# step 5050, cross_entropy 1.16767
# step 5100, cross_entropy 1.14935
# step 5150, cross_entropy 1.17736
# step 5200, cross_entropy 1.14806
# step 5250, cross_entropy 1.11094
# test accuracy 0.561
# step 5300, cross_entropy 1.16918
# step 5350, cross_entropy 1.14519
# step 5400, cross_entropy 1.10897
# step 5450, cross_entropy 1.11146
# step 5500, cross_entropy 1.09719
# test accuracy 0.578
# step 5550, cross_entropy 1.09916
# step 5600, cross_entropy 1.13373
# step 5650, cross_entropy 1.12003
# step 5700, cross_entropy 1.12129
# step 5750, cross_entropy 1.10378
# test accuracy 0.642
# step 5800, cross_entropy 1.13473
# step 5850, cross_entropy 1.07807
# step 5900, cross_entropy 1.08285
# step 5950, cross_entropy 1.11831
# step 6000, cross_entropy 1.09794
# test accuracy 0.632
# step 6050, cross_entropy 1.03152
# step 6100, cross_entropy 1.08597
# step 6150, cross_entropy 1.05959
# step 6200, cross_entropy 1.03758
# step 6250, cross_entropy 1.04705
# test accuracy 0.598
# step 6300, cross_entropy 1.08081
# step 6350, cross_entropy 1.05261
# step 6400, cross_entropy 1.07007
# step 6450, cross_entropy 1.06785
# step 6500, cross_entropy 1.00009
# test accuracy 0.626
# step 6550, cross_entropy 1.07019
# step 6600, cross_entropy 1.01578
# step 6650, cross_entropy 1.04833
# step 6700, cross_entropy 1.03451
# step 6750, cross_entropy 1.02517
# test accuracy 0.615
# step 6800, cross_entropy 1.05178
# step 6850, cross_entropy 1.03392
# step 6900, cross_entropy 1.00068
# step 6950, cross_entropy 1.01842
# step 7000, cross_entropy 1.02573
# test accuracy 0.638
# step 7050, cross_entropy 1.01248
# step 7100, cross_entropy 0.984976
# step 7150, cross_entropy 1.01881
# step 7200, cross_entropy 1.00876
# step 7250, cross_entropy 1.01721
# test accuracy 0.666
# step 7300, cross_entropy 1.01257
# step 7350, cross_entropy 0.996897
# step 7400, cross_entropy 0.987638
# step 7450, cross_entropy 0.998506
# step 7500, cross_entropy 1.03966
# test accuracy 0.644
# step 7550, cross_entropy 1.00078
# step 7600, cross_entropy 0.988901
# step 7650, cross_entropy 0.96259
# step 7700, cross_entropy 0.984477
# step 7750, cross_entropy 0.972945
# test accuracy 0.629
# step 7800, cross_entropy 0.968733
# step 7850, cross_entropy 0.972867
# step 7900, cross_entropy 0.998175
# step 7950, cross_entropy 0.966541
# step 8000, cross_entropy 0.948061
# test accuracy 0.65
# step 8050, cross_entropy 0.937164
# step 8100, cross_entropy 0.973359
# step 8150, cross_entropy 0.924855
# step 8200, cross_entropy 0.955689
# step 8250, cross_entropy 0.915852
# test accuracy 0.655
# step 8300, cross_entropy 0.967527
# step 8350, cross_entropy 0.864116
# step 8400, cross_entropy 0.946343
# step 8450, cross_entropy 0.953982
# step 8500, cross_entropy 0.944811
# test accuracy 0.647
# step 8550, cross_entropy 0.930239
# step 8600, cross_entropy 0.931354
# step 8650, cross_entropy 0.893538
# step 8700, cross_entropy 0.921804
# step 8750, cross_entropy 0.940234
# test accuracy 0.689
# step 8800, cross_entropy 0.90604
# step 8850, cross_entropy 0.919462
# step 8900, cross_entropy 0.904121
# step 8950, cross_entropy 0.926662
# step 9000, cross_entropy 0.908665
# test accuracy 0.656
# step 9050, cross_entropy 0.933653
# step 9100, cross_entropy 0.877151
# step 9150, cross_entropy 0.877867
# step 9200, cross_entropy 0.905773
# step 9250, cross_entropy 0.910393
# test accuracy 0.669
# step 9300, cross_entropy 0.89907
# step 9350, cross_entropy 0.89097
# step 9400, cross_entropy 0.896807
# step 9450, cross_entropy 0.908765
# step 9500, cross_entropy 0.927351
# test accuracy 0.713
# step 9550, cross_entropy 0.876722
# step 9600, cross_entropy 0.866322
# step 9650, cross_entropy 0.855608
# step 9700, cross_entropy 0.852204
# step 9750, cross_entropy 0.896578
# test accuracy 0.73
# step 9800, cross_entropy 0.873065
# step 9850, cross_entropy 0.892574
# step 9900, cross_entropy 0.871002
# step 9950, cross_entropy 0.886408
# step 10000, cross_entropy 0.866146
# test accuracy 0.691
# step 10050, cross_entropy 0.854233
# step 10100, cross_entropy 0.860568
# step 10150, cross_entropy 0.837926
# step 10200, cross_entropy 0.82857
# step 10250, cross_entropy 0.849154
# test accuracy 0.685
# step 10300, cross_entropy 0.820732
# step 10350, cross_entropy 0.85271
# step 10400, cross_entropy 0.831296
# step 10450, cross_entropy 0.852742
# step 10500, cross_entropy 0.842535
# test accuracy 0.725
# step 10550, cross_entropy 0.829253
# step 10600, cross_entropy 0.868485
# step 10650, cross_entropy 0.863891
# step 10700, cross_entropy 0.81755
# step 10750, cross_entropy 0.808041
# test accuracy 0.682
# step 10800, cross_entropy 0.856786
# step 10850, cross_entropy 0.83525
# step 10900, cross_entropy 0.833078
# step 10950, cross_entropy 0.821249
# step 11000, cross_entropy 0.847811
# test accuracy 0.695
# step 11050, cross_entropy 0.821942
# step 11100, cross_entropy 0.807478
# step 11150, cross_entropy 0.826257
# step 11200, cross_entropy 0.871698
# step 11250, cross_entropy 0.808262
# test accuracy 0.658
# step 11300, cross_entropy 0.830174
# step 11350, cross_entropy 0.826436
# step 11400, cross_entropy 0.850895
# step 11450, cross_entropy 0.783854
# step 11500, cross_entropy 0.821706
# test accuracy 0.697
# step 11550, cross_entropy 0.801731
# step 11600, cross_entropy 0.823657
# step 11650, cross_entropy 0.776543
# step 11700, cross_entropy 0.817853
# step 11750, cross_entropy 0.814939
# test accuracy 0.713
# step 11800, cross_entropy 0.770805
# step 11850, cross_entropy 0.800401
# step 11900, cross_entropy 0.754167
# step 11950, cross_entropy 0.814545
# step 12000, cross_entropy 0.788984
# test accuracy 0.687
# step 12050, cross_entropy 0.808967
# step 12100, cross_entropy 0.765647
# step 12150, cross_entropy 0.764795
# step 12200, cross_entropy 0.832812
# step 12250, cross_entropy 0.770351
# test accuracy 0.691
# step 12300, cross_entropy 0.793644
# step 12350, cross_entropy 0.764768
# step 12400, cross_entropy 0.795505
# step 12450, cross_entropy 0.769799
# step 12500, cross_entropy 0.792767
# test accuracy 0.712
# step 12550, cross_entropy 0.799644
# step 12600, cross_entropy 0.74622
# step 12650, cross_entropy 0.742964
# step 12700, cross_entropy 0.793409
# step 12750, cross_entropy 0.759208
# test accuracy 0.721
# step 12800, cross_entropy 0.769879
# step 12850, cross_entropy 0.73855
# step 12900, cross_entropy 0.753841
# step 12950, cross_entropy 0.798602
# step 13000, cross_entropy 0.749729
# test accuracy 0.686
# step 13050, cross_entropy 0.769202
# step 13100, cross_entropy 0.747923
# step 13150, cross_entropy 0.724407
# step 13200, cross_entropy 0.712165
# step 13250, cross_entropy 0.785838
# test accuracy 0.741
# step 13300, cross_entropy 0.748017
# step 13350, cross_entropy 0.771846
# step 13400, cross_entropy 0.77505
# step 13450, cross_entropy 0.767818
# step 13500, cross_entropy 0.732829
# test accuracy 0.732
# step 13550, cross_entropy 0.739707
# step 13600, cross_entropy 0.723245
# step 13650, cross_entropy 0.716533
# step 13700, cross_entropy 0.738326
# step 13750, cross_entropy 0.708877
# test accuracy 0.732
# step 13800, cross_entropy 0.757738
# step 13850, cross_entropy 0.768459
# step 13900, cross_entropy 0.744689
# step 13950, cross_entropy 0.743943
# step 14000, cross_entropy 0.709718
# test accuracy 0.74
# step 14050, cross_entropy 0.754053
# step 14100, cross_entropy 0.725327
# step 14150, cross_entropy 0.747085
# step 14200, cross_entropy 0.692108
# step 14250, cross_entropy 0.71896
# test accuracy 0.735
# step 14300, cross_entropy 0.731459
# step 14350, cross_entropy 0.733179
# step 14400, cross_entropy 0.75676
# step 14450, cross_entropy 0.721806
# step 14500, cross_entropy 0.749855
# test accuracy 0.724
# step 14550, cross_entropy 0.725716
# step 14600, cross_entropy 0.702022
# step 14650, cross_entropy 0.715573
# step 14700, cross_entropy 0.709406
# step 14750, cross_entropy 0.719693
# test accuracy 0.725
# step 14800, cross_entropy 0.73929
# step 14850, cross_entropy 0.697678
# step 14900, cross_entropy 0.721245
# step 14950, cross_entropy 0.694284
# step 15000, cross_entropy 0.714659
# test accuracy 0.757
# step 15050, cross_entropy 0.713713
# step 15100, cross_entropy 0.691467
# step 15150, cross_entropy 0.693835
# step 15200, cross_entropy 0.683335
# step 15250, cross_entropy 0.699154
# test accuracy 0.75
# step 15300, cross_entropy 0.734795
# step 15350, cross_entropy 0.687853
# step 15400, cross_entropy 0.728976
# step 15450, cross_entropy 0.712251
# step 15500, cross_entropy 0.721562
# test accuracy 0.744
# step 15550, cross_entropy 0.67842
# step 15600, cross_entropy 0.654329
# step 15650, cross_entropy 0.707463
# step 15700, cross_entropy 0.690105
# step 15750, cross_entropy 0.70011
# test accuracy 0.748
# step 15800, cross_entropy 0.671742
# step 15850, cross_entropy 0.681983
# step 15900, cross_entropy 0.694736
# step 15950, cross_entropy 0.663597
# step 16000, cross_entropy 0.67544
# test accuracy 0.722
# step 16050, cross_entropy 0.682948
# step 16100, cross_entropy 0.669638
# step 16150, cross_entropy 0.672619
# step 16200, cross_entropy 0.704448
# step 16250, cross_entropy 0.658417
# test accuracy 0.655
# step 16300, cross_entropy 0.69292
# step 16350, cross_entropy 0.666681
# step 16400, cross_entropy 0.665299
# step 16450, cross_entropy 0.635625
# step 16500, cross_entropy 0.704406
# test accuracy 0.731
# step 16550, cross_entropy 0.654511
# step 16600, cross_entropy 0.661917
# step 16650, cross_entropy 0.666679
# step 16700, cross_entropy 0.677934
# step 16750, cross_entropy 0.661969
# test accuracy 0.752
# step 16800, cross_entropy 0.657352
# step 16850, cross_entropy 0.682109
# step 16900, cross_entropy 0.651847
# step 16950, cross_entropy 0.659962
# step 17000, cross_entropy 0.640915
# test accuracy 0.749
# step 17050, cross_entropy 0.647695
# step 17100, cross_entropy 0.640911
# step 17150, cross_entropy 0.640711
# step 17200, cross_entropy 0.634408
# step 17250, cross_entropy 0.634878
# test accuracy 0.776
# step 17300, cross_entropy 0.69902
# step 17350, cross_entropy 0.64925
# step 17400, cross_entropy 0.61696
# step 17450, cross_entropy 0.646811
# step 17500, cross_entropy 0.646368
# test accuracy 0.737
# step 17550, cross_entropy 0.67714
# step 17600, cross_entropy 0.635336
# step 17650, cross_entropy 0.65237
# step 17700, cross_entropy 0.647116
# step 17750, cross_entropy 0.633753
# test accuracy 0.75
# step 17800, cross_entropy 0.664139
# step 17850, cross_entropy 0.630703
# step 17900, cross_entropy 0.63608
# step 17950, cross_entropy 0.657393
# step 18000, cross_entropy 0.643852
# test accuracy 0.726
# step 18050, cross_entropy 0.593366
# step 18100, cross_entropy 0.602405
# step 18150, cross_entropy 0.631233
# step 18200, cross_entropy 0.626277
# step 18250, cross_entropy 0.613584
# test accuracy 0.778
# step 18300, cross_entropy 0.617656
# step 18350, cross_entropy 0.644665
# step 18400, cross_entropy 0.643791
# step 18450, cross_entropy 0.65451
# step 18500, cross_entropy 0.627694
# test accuracy 0.764
# step 18550, cross_entropy 0.616527
# step 18600, cross_entropy 0.623275
# step 18650, cross_entropy 0.61783
# step 18700, cross_entropy 0.648336
# step 18750, cross_entropy 0.588936
# test accuracy 0.778
# step 18800, cross_entropy 0.637936
# step 18850, cross_entropy 0.619864
# step 18900, cross_entropy 0.618756
# step 18950, cross_entropy 0.628652
# step 19000, cross_entropy 0.592406
# test accuracy 0.72
# step 19050, cross_entropy 0.609192
# step 19100, cross_entropy 0.581122
# step 19150, cross_entropy 0.618943
# step 19200, cross_entropy 0.590988
# step 19250, cross_entropy 0.623459
# test accuracy 0.755
# step 19300, cross_entropy 0.619758
# step 19350, cross_entropy 0.620733
# step 19400, cross_entropy 0.57056
# step 19450, cross_entropy 0.62559
# step 19500, cross_entropy 0.591208
# test accuracy 0.714
# step 19550, cross_entropy 0.589959
# step 19600, cross_entropy 0.627553
# step 19650, cross_entropy 0.588438
# step 19700, cross_entropy 0.580052
# step 19750, cross_entropy 0.59385
# test accuracy 0.765
# step 19800, cross_entropy 0.587834
# step 19850, cross_entropy 0.597121
# step 19900, cross_entropy 0.623776
# step 19950, cross_entropy 0.585275

# %%
with tf.Graph().as_default(), tf.device("/cpu:0"):
        train_data, test_data = cifar10_input()
        
        train_batch = train_data.dist_batch(BATCH_SIZE, 20000)
        images, labels = test_data.dist_batch(EVAL_SIZE, 4000)

        keep_prob = tf.placeholder(tf.float32)
        lr = tf.placeholder(tf.float32)

        logit = model.inference(images, keep_prob)
        accuracy = tf.reduce_mean(tf.cast(tf.nn.in_top_k(logit, labels, 1),tf.float32))
        tf.get_variable_scope().reuse_variables()
        
        opt = tf.train.GradientDescentOptimizer(lr)
        
        tower_grads = []
        tower_losses = []
        
        for i in range(NUM_GPUS):
            with tf.device('/gpu:%d' % i):
                with tf.name_scope('%s_%d' % ('tower', i)) as scope:
                    loss = tower_loss(train_batch, scope)
                    grads = opt.compute_gradients(loss)
                    tower_losses.append(loss)
                    tower_grads.append(grads)
                    
        grads = average_grads(tower_grads)
        mean_loss = tf.reduce_mean(tower_losses)
  
        train_op = opt.apply_gradients(grads)
        sess = tf.Session()
        
        rate = 0.1
        least = 10.
        mean = 0.
        count = 0.
        highest = 0.
    
        sess.run(tf.initialize_all_variables())
        tf.train.start_queue_runners(sess=sess)
        for i in range(20000):
            _, cross_entropy = sess.run([train_op, mean_loss], feed_dict = {keep_prob: 0.5,
                                                                       lr:rate})
            mean = mean + cross_entropy/200
            if (i+1)%200 == 0 and i>0:
                print("step %d, cross_entropy %g"%(i, cross_entropy))
      
                if mean > least:
                    count = count+1
                    if count > 4:
                        rate = rate/2.0
                        count = 0
                    else:
                        count = 0
                        least = mean
                
                mean=0.
        
            if (i+1)%200 == 0 and i>0:
                eval_accuracy = sess.run(accuracy)
                if eval_accuracy > highest:
                    highest = eval_accuracy
                print("test accuracy %g"%(eval_accuracy))
                
        print("highest accuracy: %g"%(highest))
# Out:
# step 199, cross_entropy 2.62666
# test accuracy 0.173
# step 399, cross_entropy 2.2112
# test accuracy 0.243
# step 599, cross_entropy 2.09563
# test accuracy 0.225
# step 799, cross_entropy 1.99115
# test accuracy 0.219
# step 999, cross_entropy 2.05348
# test accuracy 0.234
# step 1199, cross_entropy 1.94465
# test accuracy 0.248
# step 1399, cross_entropy 2.03732
# test accuracy 0.284
# step 1599, cross_entropy 1.80604
# test accuracy 0.279
# step 1799, cross_entropy 2.10421
# test accuracy 0.296
# step 1999, cross_entropy 1.70636
# test accuracy 0.248
# step 2199, cross_entropy 1.88579
# test accuracy 0.272
# step 2399, cross_entropy 2.24687
# test accuracy 0.302
# step 2599, cross_entropy 1.7379
# test accuracy 0.297
# step 2799, cross_entropy 2.03177
# test accuracy 0.278
# step 2999, cross_entropy 2.0558
# test accuracy 0.273
# step 3199, cross_entropy 1.77695
# test accuracy 0.259
# step 3399, cross_entropy 1.62078
# test accuracy 0.303
# step 3599, cross_entropy 2.21696
# test accuracy 0.28
# step 3799, cross_entropy 1.64462
# test accuracy 0.254
# step 3999, cross_entropy 1.77367
# test accuracy 0.316
# step 4199, cross_entropy 1.38039
# test accuracy 0.313
# step 4399, cross_entropy 1.58038
# test accuracy 0.272
# step 4599, cross_entropy 1.66054
# test accuracy 0.289
# step 4799, cross_entropy 1.66812
# test accuracy 0.372
# step 4999, cross_entropy 2.07001
# test accuracy 0.334
# step 5199, cross_entropy 2.75798
# test accuracy 0.29
# step 5399, cross_entropy 1.24496
# test accuracy 0.3
# step 5599, cross_entropy 1.71716
# test accuracy 0.402
# step 5799, cross_entropy 2.49757
# test accuracy 0.366
# step 5999, cross_entropy 1.8149
# test accuracy 0.35
# step 6199, cross_entropy 1.78745
# test accuracy 0.412
# step 6399, cross_entropy 1.52345
# test accuracy 0.422
# step 6599, cross_entropy 1.43069
# test accuracy 0.386
# step 6799, cross_entropy 1.52427
# test accuracy 0.367
# step 6999, cross_entropy 1.80788
# test accuracy 0.405
# step 7199, cross_entropy 1.9408
# test accuracy 0.377
# step 7399, cross_entropy 1.75471
# test accuracy 0.377
# step 7599, cross_entropy 1.80256
# test accuracy 0.441
# step 7799, cross_entropy 1.80727
# test accuracy 0.46
# step 7999, cross_entropy 1.35287
# test accuracy 0.374
# step 8199, cross_entropy 1.62671
# test accuracy 0.51
# step 8399, cross_entropy 1.1817
# test accuracy 0.433
# step 8599, cross_entropy 1.24803
# test accuracy 0.413
# step 8799, cross_entropy 1.42025
# test accuracy 0.517
# step 8999, cross_entropy 1.13775
# test accuracy 0.495
# step 9199, cross_entropy 1.12792
# test accuracy 0.447
# step 9399, cross_entropy 1.28206
# test accuracy 0.431
# step 9599, cross_entropy 1.21749
# test accuracy 0.467
# step 9799, cross_entropy 1.33424
# test accuracy 0.483
# step 9999, cross_entropy 1.56823
# test accuracy 0.473
# step 10199, cross_entropy 1.36501
# test accuracy 0.473
# step 10399, cross_entropy 1.47657
# test accuracy 0.467
# step 10599, cross_entropy 2.07381
# test accuracy 0.479
# step 10799, cross_entropy 1.41245
# test accuracy 0.486
# step 10999, cross_entropy 1.22449
# test accuracy 0.556
# step 11199, cross_entropy 1.37796
# test accuracy 0.531
# step 11399, cross_entropy 1.66395
# test accuracy 0.5
# step 11599, cross_entropy 1.33142
# test accuracy 0.468
# step 11799, cross_entropy 1.83494
# test accuracy 0.525
# step 11999, cross_entropy 1.6377
# test accuracy 0.461
# step 12199, cross_entropy 1.71505
# test accuracy 0.503
# step 12399, cross_entropy 1.07697
# test accuracy 0.565
# step 12599, cross_entropy 1.41103
# test accuracy 0.522
# step 12799, cross_entropy 1.32467
# test accuracy 0.538
# step 12999, cross_entropy 1.29348
# test accuracy 0.574
# step 13199, cross_entropy 1.43403
# test accuracy 0.564
# step 13399, cross_entropy 1.07889
# test accuracy 0.558
# step 13599, cross_entropy 1.51244
# test accuracy 0.502
# step 13799, cross_entropy 1.44507
# test accuracy 0.551
# step 13999, cross_entropy 1.04949
# test accuracy 0.6
# step 14199, cross_entropy 1.61254
# test accuracy 0.559
# step 14399, cross_entropy 1.27143
# test accuracy 0.58
# step 14599, cross_entropy 2.03769
# test accuracy 0.558
# step 14799, cross_entropy 1.12588
# test accuracy 0.554
# step 14999, cross_entropy 1.37271
# test accuracy 0.552
# step 15199, cross_entropy 1.98242
# test accuracy 0.519
# step 15399, cross_entropy 1.3615
# test accuracy 0.52
# step 15599, cross_entropy 1.35071
# test accuracy 0.537
# step 15799, cross_entropy 1.52084
# test accuracy 0.569
# step 15999, cross_entropy 1.53953
# test accuracy 0.587
# step 16199, cross_entropy 1.63915
# test accuracy 0.502
# step 16399, cross_entropy 1.49868
# test accuracy 0.542
# step 16599, cross_entropy 1.62695
# test accuracy 0.588
# step 16799, cross_entropy 1.32967
# test accuracy 0.547
# step 16999, cross_entropy 1.00721
# test accuracy 0.604
# step 17199, cross_entropy 1.36868
# test accuracy 0.552
# step 17399, cross_entropy 1.43333
# test accuracy 0.489
# step 17599, cross_entropy 0.870866
# test accuracy 0.556
# step 17799, cross_entropy 1.44303
# test accuracy 0.601
# step 17999, cross_entropy 0.958718
# test accuracy 0.582
# step 18199, cross_entropy 1.01517
# test accuracy 0.624
# step 18399, cross_entropy 1.07346
# test accuracy 0.59
# step 18599, cross_entropy 1.01115
# test accuracy 0.589
# step 18799, cross_entropy 0.882695
# test accuracy 0.531
# step 18999, cross_entropy 1.77008
# test accuracy 0.557
# step 19199, cross_entropy 1.19403
# test accuracy 0.628
# step 19399, cross_entropy 0.7771
# test accuracy 0.642
# step 19599, cross_entropy 0.705875
# test accuracy 0.608
# step 19799, cross_entropy 0.687546
# test accuracy 0.57
# step 19999, cross_entropy 1.16213
# test accuracy 0.578
# highest accuracy: 0.642

# %%
rate = 0.0002
with tf.device('/cpu:0'):
    for i in range(4000):
            _, cross_entropy = sess.run([train_op, mean_loss], feed_dict = {keep_prob: 0.5,
                                                                       lr:rate})
            mean = mean + cross_entropy/200
            if (i+1)%200 == 0 and i>0:
                print("step %d, cross_entropy %g"%(i, cross_entropy))          
                mean=0.
        
            if (i+1)%200 == 0 and i>0:
                eval_accuracy = sess.run(accuracy)
                if eval_accuracy > highest:
                    highest = eval_accuracy
                print("test accuracy %g"%(eval_accuracy))
                
    print("highest accuracy: %g"%(highest))
# Out:
# step 199, cross_entropy 0.552647
# test accuracy 0.704
# step 399, cross_entropy 0.832568
# test accuracy 0.725
# step 599, cross_entropy 1.28938
# test accuracy 0.705
# step 799, cross_entropy 0.739266
# test accuracy 0.7
# step 999, cross_entropy 0.728572
# test accuracy 0.749
# step 1199, cross_entropy 1.34703
# test accuracy 0.727
# step 1399, cross_entropy 1.09868
# test accuracy 0.717
# step 1599, cross_entropy 0.779814
# test accuracy 0.703
# step 1799, cross_entropy 0.89581
# test accuracy 0.747
# step 1999, cross_entropy 0.680895
# test accuracy 0.728
# step 2199, cross_entropy 0.667762
# test accuracy 0.724
# step 2399, cross_entropy 0.951571
# test accuracy 0.731
# step 2599, cross_entropy 0.976929
# test accuracy 0.71
# step 2799, cross_entropy 1.38839
# test accuracy 0.703
# step 2999, cross_entropy 0.418734
# test accuracy 0.709
# step 3199, cross_entropy 0.792785
# test accuracy 0.734
# step 3399, cross_entropy 0.858384
# test accuracy 0.705
# step 3599, cross_entropy 0.747864
# test accuracy 0.713
# step 3799, cross_entropy 0.890994
# test accuracy 0.701
# step 3999, cross_entropy 0.474894
# test accuracy 0.718
# highest accuracy: 0.749
